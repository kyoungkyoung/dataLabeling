# %%
import os
os.getcwd()
# Out:
# 'c:\\Github\\05_yoloV11'

# %%
import cv2
import os

# white bg # Eclipe # Hush
# output_folder ="6th_mix_2_capture_01"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_01", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_204646.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 239 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_01'

# %%
import cv2
import os

# white bg # snack # Hush
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_wh02", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_205008.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 265 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_wh02'

# %%
import cv2
import os

# white bg # Eclipse # snack
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_wh03", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_205432.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 241 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_wh03'

# %%
import cv2
import os

# black bg # Eclipse # Hush
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_bk01", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_205808.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 287 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_bk01'

# %%
import cv2
import os

# black bg # Eclipse # snack
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_bk02", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_210218.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 281 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_bk02'

# %%
import cv2
import os

# black bg # snack # hush # part 1
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_bk03", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_210558.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 230 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_bk03'

# %%
import cv2
import os

# black bg # snack # hush # part 2
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_bk04", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_210940.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 89 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_bk04'

# %%
import cv2
import os

# wood bg # Eclipse # hush
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_wd01", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_211531.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 246 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_wd01'

# %%
import cv2
import os

# wood bg # Eclipse # snack
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_wd02", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break

        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_211839.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 295 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_wd02'

# %%
import cv2
import os

# wood bg # snack # hush
# output_folder ="6th_mix_2_capture_00"

def capture_frames(video_path, output_folder = "6th_mix_2_capture_wd03", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix_2_capture_bg01"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break
 
        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "20241017_212224.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 284 frames to 'C:\Github\05_yoloV11\6th_picture\6th_mix_2_capture_wd03'

# %% [markdown]
# # 3mix

# %%
# white bg
# output_folder ="6th_mix_2_capture_00"

import cv2
import os


def capture_frames(video_path, output_folder = "mix3_wh", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix3_wh"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break
 
        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "./6th_mix3_wh/20241018_120752.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 181 frames to 'c:\Github\05_yoloV11\mix3_wh'

# %%
# black bg
# output_folder ="6th_mix_2_capture_00"

import cv2
import os


def capture_frames(video_path, output_folder = "mix3_bk", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix3_wh"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break
 
        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "./6th_mix3_wh/20241018_121228.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 174 frames to 'c:\Github\05_yoloV11\mix3_bk'

# %%
# wood bg
# output_folder ="6th_mix_2_capture_00"

import cv2
import os


def capture_frames(video_path, output_folder = "mix3_wd", fps=2):
    """
    동영상에서 특정 프레임 레이트로 이미지를 추출하여 저장합니다.

    Args:
        video_path (str): 동영상 파일 경로
        output_folder (str): 이미지를 저장할 폴더 이름. 기본값은 "6th_mix3_wh"
        fps (int): 초당 저장할 프레임 수 (기본값: 2)
    """
    # 동영상 불러오기
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print(f"Error: Cannot open video file: {video_path}")
        return

    # 프레임 정보 가져오기
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # 출력 폴더 생성
    output_path = os.path.join(os.getcwd(), output_folder)
    os.makedirs(output_path, exist_ok=True)

    # 프레임 추출 및 저장
    current_frame = 0
    saved_frame_count = 0
    while current_frame < frame_count:
        ret, frame = video.read()  # 프레임 읽기

        if not ret:
            break
 
        # 지정된 프레임 레이트에 따라 저장
        if current_frame % int(frame_rate / fps) == 0:
            file_name = f"frame_{saved_frame_count:04d}.jpg"  # 파일명 형식
            file_path = os.path.join(output_path, file_name)
            cv2.imwrite(file_path, frame)
            saved_frame_count += 1

        current_frame += 1

    video.release()
    print(f"Saved {saved_frame_count} frames to '{output_path}'")


# 사용 예시
video_file = "./6th_mix3_wh/20241018_131143.mp4"  # 동영상 파일 경로로 변경
capture_frames(video_file, fps=2)  # 1초에 2 프레임 저장, 폴더명은 기본값 사용
# Out:
# Saved 176 frames to 'c:\Github\05_yoloV11\mix3_wd'
